# %%
# !unzip drowsiness.v1i.yolov8.zip -d drowsiness_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.6d5d4e3d24afaba7ba3dcce4fb7d3feb.txt
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.8565729e8bea3100bf263ed063ef6f3f.txt
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.908fc2f47381593e61107070231a2434.txt
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.9266c373afa8091ba12860c1cd7be8fa.txt
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.ab56c0ab42393a31c258091248653b74.txt
#   inflating: drowsiness_dataset/train/labels/tired-young-woman-asleep-on-steering-wheel-in-her-car-2BJ8C91_jpg.rf.b44d438d255eab261020853e86c49345.txt
# ...

# %%
# !ls drowsiness_dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !ls drowsiness_dataset/train
# Out:
# images	labels

# %%
# !cat drowsiness_dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 11
# names: ['Attentive eye', 'Drowsy eye', 'Eyeclosed', 'Open-Mouth', 'Yawn', 'asleep', 'close', 'closed', 'noYawn', 'open', 'yawn']
#
# roboflow:
#   workspace: vinoth-sqvrp
#   project: drowsiness-driver-fwsqb
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/vinoth-sqvrp/drowsiness-driver-fwsqb/dataset/1

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo detect train \
model=yolov8m.pt \
data=drowsiness_dataset/data.yaml \
imgsz=768 \
epochs=150 \
batch=16 \
optimizer=AdamW \
lr0=0.001 \
cos_lr=True \
workers=8
# Out:
# ...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download('runs/detect/train/weights/best.pt')

# %%
runs/detect/train/weights/best.pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2271496933.py in <cell line: 0>()
# ----> 1 runs/detect/train/weights/best.pt
#
# NameError: name 'runs' is not defined
